# %% [markdown]
# #### Ángel Martínez

# %% [markdown]
# # Sprint 1
#
# ## Nivel 1
#
# ### Ejercicio 1
#
# #### Instalar Anaconda con Python 3 y Jupiter Notebook

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ejercicio 2
#
# #### Realizar cálculos sencillos.

# %%
nombre = "Ángel"
apellido = "Martínez"
edad = 27

listaDatos = [nombre, apellido, edad]

print(listaDatos)
# Out:
# ['Ángel', 'Martínez', 27]

# %%
x = 5
y = 10

print(x + y)

# %%
x = 25.5
y = 50.5

print(x * y)
# Out:
# 1287.75

# %% [markdown]
# ### Ejercicio 3
#
# #### Crear títulos, listas, añadir imágenes, etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pip install jupyterthemes
# Out:
# ...
#
# ...

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t onedork -T -N -kl

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Nivel 2
#
# #### Exportar el Notebook como pdf y como html.

# %% [markdown]
# #### Como html
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Como pdf
#
# En este caso he utilizado el archivo .html que he descargado desde el Jupyter, y posteriormente un conversor de html a pdf.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Nivel 3
#
# #### Instalar Nbextensions al Notebook de Jupyter.

# %% [markdown]
# ![image.png](attachment:image.png)
